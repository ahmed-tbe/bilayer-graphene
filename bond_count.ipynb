# %% [markdown]
# <a href="https://colab.research.google.com/github/ahmed-tbe/bilayer-graphene/blob/main/bond_count.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from collections import defaultdict

file_path = "bonds.reax"
BOND_ORDER_CUTOFF = 0.3
CARBON_TYPE = 1
FLUORINE_TYPE = 2

cf_bond_counts = defaultdict(int)

def process_timestep(timestep, atoms):
    """Counts unique C–F bonds for a given timestep."""
    id_type_map = {int(a[0]): int(a[1]) for a in atoms}
    cf_bonds = set()

    for a in atoms:
        atom_id = int(a[0])
        atom_type = int(a[1])
        num_neighbors = int(a[2])

        if num_neighbors == 0:
            continue

        neighbor_ids = list(map(int, a[3:3 + num_neighbors]))
        bond_orders = list(map(float, a[3 + num_neighbors:3 + 2 * num_neighbors]))

        for neighbor_id, bond_order in zip(neighbor_ids, bond_orders):
            neighbor_type = id_type_map.get(neighbor_id)
            if bond_order > BOND_ORDER_CUTOFF:
                # Check for C-F bond (either direction)
                if (atom_type == CARBON_TYPE and neighbor_type == FLUORINE_TYPE) or \
                   (atom_type == FLUORINE_TYPE and neighbor_type == CARBON_TYPE):
                    bond_pair = tuple(sorted((atom_id, neighbor_id)))
                    cf_bonds.add(bond_pair)

    cf_bond_counts[timestep] = len(cf_bonds)

# Read and parse file
with open(file_path, 'r') as f:
    lines = f.readlines()

timestep = None
atoms = []

for line in lines:
    line = line.strip()
    if not line:
        continue
    if line.startswith("# Timestep"):
        if timestep is not None:
            process_timestep(timestep, atoms)
        timestep = int(line.split()[-1])
        atoms = []
    elif not line.startswith("#"):
        split_line = line.split()
        if len(split_line) < 3:
            print(f"⚠️ Unexpected line format at timestep {timestep}: {line}")
            continue
        atoms.append(split_line)

# Process last timestep
if timestep is not None:
    process_timestep(timestep, atoms)

# Output results
for ts in sorted(cf_bond_counts):
    print(f"Timestep {ts}: {cf_bond_counts[ts]} unique C–F bonds")

import matplotlib.pyplot as plt

# Sort the data
sorted_timesteps = sorted(cf_bond_counts.keys())
bond_values = [cf_bond_counts[ts] for ts in sorted_timesteps]

# Plotting
plt.figure(figsize=(10, 5))
plt.plot(sorted_timesteps, bond_values, linestyle='-', color='teal')  # no markers
plt.xlabel("Timestep")
plt.ylabel("Number of Unique C–F Bonds")
plt.title("C–F Bond Count Over Time")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Timestep 64: 0 unique C–F bonds
# Timestep 100: 0 unique C–F bonds
# Timestep 150: 0 unique C–F bonds
# Timestep 200: 0 unique C–F bonds
# Timestep 250: 0 unique C–F bonds
# Timestep 300: 0 unique C–F bonds
# Timestep 350: 0 unique C–F bonds
# Timestep 400: 0 unique C–F bonds
# Timestep 450: 0 unique C–F bonds
# Timestep 500: 0 unique C–F bonds
# Timestep 550: 0 unique C–F bonds
# Timestep 600: 0 unique C–F bonds
# Timestep 650: 0 unique C–F bonds
# Timestep 700: 0 unique C–F bonds
# Timestep 750: 0 unique C–F bonds
# Timestep 800: 0 unique C–F bonds
# Timestep 850: 0 unique C–F bonds
# Timestep 900: 0 unique C–F bonds
# Timestep 950: 0 unique C–F bonds
# Timestep 1000: 0 unique C–F bonds
# Timestep 1050: 0 unique C–F bonds
# Timestep 1100: 0 unique C–F bonds
# Timestep 1150: 0 unique C–F bonds
# Timestep 1200: 0 unique C–F bonds
# Timestep 1250: 0 unique C–F bonds
# Timestep 1300: 0 unique C–F bonds
# Timestep 1350: 0 unique C–F bonds
# Timestep 1400: 0 unique C–F bonds
# Timestep 1450: 0 unique C–F bonds
# Timestep 1500: 0 unique C–F bonds
# Timestep 1550: 0 unique C–F bonds
# Timestep 1600: 0 unique C–F bonds
# Timestep 1650: 0 unique C–F bonds
# Timestep 1700: 0 unique C–F bonds
# Timestep 1750: 0 unique C–F bonds
# Timestep 1800: 0 unique C–F bonds
# Timestep 1850: 0 unique C–F bonds
# Timestep 1900: 0 unique C–F bonds
# Timestep 1950: 0 unique C–F bonds
# Timestep 2000: 0 unique C–F bonds
# Timestep 2050: 0 unique C–F bonds
# Timestep 2100: 0 unique C–F bonds
# Timestep 2150: 0 unique C–F bonds
# Timestep 2200: 0 unique C–F bonds
# Timestep 2250: 0 unique C–F bonds
# Timestep 2300: 0 unique C–F bonds
# Timestep 2350: 0 unique C–F bonds
# Timestep 2400: 0 unique C–F bonds
# Timestep 2450: 0 unique C–F bonds
# Timestep 2500: 0 unique C–F bonds
# Timestep 2550: 0 unique C–F bonds
# Timestep 2600: 0 unique C–F bonds
# Timestep 2650: 0 unique C–F bonds
# Timestep 2700: 0 unique C–F bonds
# Timestep 2750: 0 unique C–F bonds
# Timestep 2800: 0 unique C–F bonds
# Timestep 2850: 0 unique C–F bonds
# Timestep 2900: 0 unique C–F bonds
# Timestep 2950: 0 unique C–F bonds
# Timestep 3000: 0 unique C–F bonds
# Timestep 3050: 0 unique C–F bonds
# Timestep 3100: 0 unique C–F bonds
# Timestep 3150: 0 unique C–F bonds
# Timestep 3200: 0 unique C–F bonds
# Timestep 3250: 0 unique C–F bonds
# Timestep 3300: 0 unique C–F bonds
# Timestep 3350: 0 unique C–F bonds
# Timestep 3400: 0 unique C–F bonds
# Timestep 3450: 0 unique C–F bonds
# Timestep 3500: 0 unique C–F bonds
# Timestep 3550: 0 unique C–F bonds
# Timestep 3600: 0 unique C–F bonds
# Timestep 3650: 0 unique C–F bonds
# Timestep 3700: 0 unique C–F bonds
# Timestep 3750: 0 unique C–F bonds
# Timestep 3800: 0 unique C–F bonds
# Timestep 3850: 0 unique C–F bonds
# Timestep 3900: 0 unique C–F bonds
# Timestep 3950: 0 unique C–F bonds
# Timestep 4000: 0 unique C–F bonds
# Timestep 4050: 0 unique C–F bonds
# Timestep 4100: 0 unique C–F bonds
# Timestep 4150: 0 unique C–F bonds
# Timestep 4200: 0 unique C–F bonds
# Timestep 4250: 0 unique C–F bonds
# Timestep 4300: 0 unique C–F bonds
# Timestep 4350: 0 unique C–F bonds
# Timestep 4400: 0 unique C–F bonds
# Timestep 4450: 0 unique C–F bonds
# Timestep 4500: 0 unique C–F bonds
# Timestep 4550: 0 unique C–F bonds
# Timestep 4600: 0 unique C–F bonds
# Timestep 4650: 0 unique C–F bonds
# Timestep 4700: 0 unique C–F bonds
# Timestep 4750: 0 unique C–F bonds
# Timestep 4800: 0 unique C–F bonds
# Timestep 4850: 0 unique C–F bonds
# Timestep 4900: 0 unique C–F bonds
# Timestep 4950: 0 unique C–F bonds
# Timestep 5000: 0 unique C–F bonds
# Timestep 5050: 0 unique C–F bonds
# Timestep 5100: 0 unique C–F bonds
# Timestep 5150: 0 unique C–F bonds
# Timestep 5200: 0 unique C–F bonds
# Timestep 5250: 0 unique C–F bonds
# Timestep 5300: 0 unique C–F bonds
# Timestep 5350: 0 unique C–F bonds
# Timestep 5400: 0 unique C–F bonds
# Timestep 5450: 0 unique C–F bonds
# Timestep 5500: 0 unique C–F bonds
# Timestep 5550: 0 unique C–F bonds
# Timestep 5600: 1 unique C–F bonds
# Timestep 5650: 1 unique C–F bonds
# Timestep 5700: 1 unique C–F bonds
# Timestep 5750: 1 unique C–F bonds
# Timestep 5800: 1 unique C–F bonds
# Timestep 5850: 1 unique C–F bonds
# Timestep 5900: 1 unique C–F bonds
# Timestep 5950: 1 unique C–F bonds
# Timestep 6000: 1 unique C–F bonds
# Timestep 6050: 1 unique C–F bonds
# Timestep 6100: 1 unique C–F bonds
# Timestep 6150: 1 unique C–F bonds
# Timestep 6200: 1 unique C–F bonds
# Timestep 6250: 1 unique C–F bonds
# Timestep 6300: 1 unique C–F bonds
# Timestep 6350: 1 unique C–F bonds
# Timestep 6400: 1 unique C–F bonds
# Timestep 6450: 1 unique C–F bonds
# Timestep 6500: 1 unique C–F bonds
# Timestep 6550: 1 unique C–F bonds
# Timestep 6600: 1 unique C–F bonds
# Timestep 6650: 1 unique C–F bonds
# Timestep 6700: 1 unique C–F bonds
# Timestep 6750: 1 unique C–F bonds
# Timestep 6800: 1 unique C–F bonds
# Timestep 6850: 1 unique C–F bonds
# Timestep 6900: 1 unique C–F bonds
# Timestep 6950: 1 unique C–F bonds
# Timestep 7000: 1 unique C–F bonds
# Timestep 7050: 1 unique C–F bonds
# Timestep 7100: 1 unique C–F bonds
# Timestep 7150: 1 unique C–F bonds
# Timestep 7200: 1 unique C–F bonds
# Timestep 7250: 1 unique C–F bonds
# Timestep 7300: 1 unique C–F bonds
# Timestep 7350: 1 unique C–F bonds
# Timestep 7400: 1 unique C–F bonds
# Timestep 7450: 1 unique C–F bonds
# Timestep 7500: 1 unique C–F bonds
# Timestep 7550: 1 unique C–F bonds
# Timestep 7600: 1 unique C–F bonds
# Timestep 7650: 1 unique C–F bonds
# Timestep 7700: 1 unique C–F bonds
# Timestep 7750: 1 unique C–F bonds
# Timestep 7800: 1 unique C–F bonds
# Timestep 7850: 1 unique C–F bonds
# Timestep 7900: 1 unique C–F bonds
# Timestep 7950: 1 unique C–F bonds
# Timestep 8000: 1 unique C–F bonds
# Timestep 8050: 1 unique C–F bonds
# Timestep 8100: 1 unique C–F bonds
# Timestep 8150: 1 unique C–F bonds
# Timestep 8200: 1 unique C–F bonds
# Timestep 8250: 1 unique C–F bonds
# Timestep 8300: 1 unique C–F bonds
# Timestep 8350: 1 unique C–F bonds
# Timestep 8400: 1 unique C–F bonds
# Timestep 8450: 1 unique C–F bonds
# Timestep 8500: 1 unique C–F bonds
# Timestep 8550: 1 unique C–F bonds
# Timestep 8600: 1 unique C–F bonds
# Timestep 8650: 2 unique C–F bonds
# Timestep 8700: 2 unique C–F bonds
# Timestep 8750: 1 unique C–F bonds
# Timestep 8800: 1 unique C–F bonds
# Timestep 8850: 1 unique C–F bonds
# Timestep 8900: 1 unique C–F bonds
# Timestep 8950: 1 unique C–F bonds
# Timestep 9000: 1 unique C–F bonds
# Timestep 9050: 1 unique C–F bonds
# Timestep 9100: 1 unique C–F bonds
# Timestep 9150: 1 unique C–F bonds
# Timestep 9200: 1 unique C–F bonds
# Timestep 9250: 1 unique C–F bonds
# Timestep 9300: 2 unique C–F bonds
# Timestep 9350: 2 unique C–F bonds
# Timestep 9400: 2 unique C–F bonds
# Timestep 9450: 2 unique C–F bonds
# Timestep 9500: 2 unique C–F bonds
# Timestep 9550: 2 unique C–F bonds
# Timestep 9600: 2 unique C–F bonds
# Timestep 9650: 2 unique C–F bonds
# Timestep 9700: 2 unique C–F bonds
# Timestep 9750: 2 unique C–F bonds
# Timestep 9800: 2 unique C–F bonds
# Timestep 9850: 2 unique C–F bonds
# Timestep 9900: 2 unique C–F bonds
# Timestep 9950: 2 unique C–F bonds
# Timestep 10000: 2 unique C–F bonds
# Timestep 10050: 2 unique C–F bonds
# Timestep 10100: 2 unique C–F bonds
# Timestep 10150: 2 unique C–F bonds
# Timestep 10200: 2 unique C–F bonds
# Timestep 10250: 2 unique C–F bonds
# Timestep 10300: 2 unique C–F bonds
# Timestep 10350: 2 unique C–F bonds
# Timestep 10400: 2 unique C–F bonds
# Timestep 10450: 3 unique C–F bonds
# Timestep 10500: 3 unique C–F bonds
# Timestep 10550: 3 unique C–F bonds
# Timestep 10600: 3 unique C–F bonds
# Timestep 10650: 3 unique C–F bonds
# Timestep 10700: 3 unique C–F bonds
# Timestep 10750: 3 unique C–F bonds
# Timestep 10800: 3 unique C–F bonds
# Timestep 10850: 3 unique C–F bonds
# Timestep 10900: 3 unique C–F bonds
# Timestep 10950: 4 unique C–F bonds
# Timestep 11000: 4 unique C–F bonds
# Timestep 11050: 3 unique C–F bonds
# Timestep 11100: 3 unique C–F bonds
# Timestep 11150: 3 unique C–F bonds
# Timestep 11200: 3 unique C–F bonds
# Timestep 11250: 4 unique C–F bonds
# Timestep 11300: 4 unique C–F bonds
# Timestep 11350: 4 unique C–F bonds
# Timestep 11400: 4 unique C–F bonds
# Timestep 11450: 4 unique C–F bonds
# Timestep 11500: 4 unique C–F bonds
# Timestep 11550: 4 unique C–F bonds
# Timestep 11600: 4 unique C–F bonds
# Timestep 11650: 4 unique C–F bonds
# Timestep 11700: 3 unique C–F bonds
# Timestep 11750: 3 unique C–F bonds
# Timestep 11800: 3 unique C–F bonds
# Timestep 11850: 4 unique C–F bonds
# Timestep 11900: 3 unique C–F bonds
# Timestep 11950: 5 unique C–F bonds
# Timestep 12000: 5 unique C–F bonds
# Timestep 12050: 6 unique C–F bonds
# Timestep 12100: 6 unique C–F bonds
# Timestep 12150: 7 unique C–F bonds
# Timestep 12200: 7 unique C–F bonds
# Timestep 12250: 8 unique C–F bonds
# Timestep 12300: 8 unique C–F bonds
# Timestep 12350: 8 unique C–F bonds
# Timestep 12400: 7 unique C–F bonds
# Timestep 12450: 7 unique C–F bonds
# Timestep 12500: 7 unique C–F bonds
# Timestep 12550: 7 unique C–F bonds
# Timestep 12600: 8 unique C–F bonds
# Timestep 12650: 8 unique C–F bonds
# Timestep 12700: 8 unique C–F bonds
# Timestep 12750: 7 unique C–F bonds
# Timestep 12800: 7 unique C–F bonds
# Timestep 12850: 7 unique C–F bonds
# Timestep 12900: 7 unique C–F bonds
# Timestep 12950: 7 unique C–F bonds
# Timestep 13000: 7 unique C–F bonds
# Timestep 13050: 7 unique C–F bonds
# Timestep 13100: 7 unique C–F bonds
# Timestep 13150: 7 unique C–F bonds
# Timestep 13200: 7 unique C–F bonds
# Timestep 13250: 7 unique C–F bonds
# Timestep 13300: 7 unique C–F bonds
# Timestep 13350: 7 unique C–F bonds
# Timestep 13400: 7 unique C–F bonds
# Timestep 13450: 7 unique C–F bonds
# Timestep 13500: 7 unique C–F bonds
# Timestep 13550: 7 unique C–F bonds
# Timestep 13600: 7 unique C–F bonds
# Timestep 13650: 7 unique C–F bonds
# Timestep 13700: 7 unique C–F bonds
# Timestep 13750: 7 unique C–F bonds
# Timestep 13800: 8 unique C–F bonds
# Timestep 13850: 8 unique C–F bonds
# Timestep 13900: 7 unique C–F bonds
# Timestep 13950: 7 unique C–F bonds
# Timestep 14000: 7 unique C–F bonds
# Timestep 14050: 9 unique C–F bonds
# Timestep 14100: 9 unique C–F bonds
# Timestep 14150: 8 unique C–F bonds
# Timestep 14200: 8 unique C–F bonds
# Timestep 14250: 8 unique C–F bonds
# Timestep 14300: 8 unique C–F bonds
# Timestep 14350: 8 unique C–F bonds
# Timestep 14400: 8 unique C–F bonds
# Timestep 14450: 8 unique C–F bonds
# Timestep 14500: 8 unique C–F bonds
# Timestep 14550: 8 unique C–F bonds
# Timestep 14600: 8 unique C–F bonds
# Timestep 14650: 8 unique C–F bonds
# Timestep 14700: 8 unique C–F bonds
# Timestep 14750: 8 unique C–F bonds
# Timestep 14800: 8 unique C–F bonds
# Timestep 14850: 8 unique C–F bonds
# Timestep 14900: 8 unique C–F bonds
# Timestep 14950: 8 unique C–F bonds
# Timestep 15000: 8 unique C–F bonds
# Timestep 15050: 8 unique C–F bonds
# Timestep 15100: 8 unique C–F bonds
# Timestep 15150: 9 unique C–F bonds
# Timestep 15200: 9 unique C–F bonds
# Timestep 15250: 9 unique C–F bonds
# Timestep 15300: 9 unique C–F bonds
# Timestep 15350: 9 unique C–F bonds
# Timestep 15400: 9 unique C–F bonds
# Timestep 15450: 9 unique C–F bonds
# Timestep 15500: 10 unique C–F bonds
# Timestep 15550: 10 unique C–F bonds
# Timestep 15600: 10 unique C–F bonds
# Timestep 15650: 10 unique C–F bonds
# Timestep 15700: 10 unique C–F bonds
# Timestep 15750: 9 unique C–F bonds
# Timestep 15800: 9 unique C–F bonds
# Timestep 15850: 9 unique C–F bonds
# Timestep 15900: 9 unique C–F bonds
# Timestep 15950: 9 unique C–F bonds
# Timestep 16000: 9 unique C–F bonds
# Timestep 16050: 9 unique C–F bonds
# Timestep 16100: 9 unique C–F bonds
# Timestep 16150: 8 unique C–F bonds
# Timestep 16200: 8 unique C–F bonds
# Timestep 16250: 8 unique C–F bonds
# Timestep 16300: 9 unique C–F bonds
# Timestep 16350: 9 unique C–F bonds
# Timestep 16400: 8 unique C–F bonds
# Timestep 16450: 8 unique C–F bonds
# Timestep 16500: 8 unique C–F bonds
# Timestep 16550: 8 unique C–F bonds
# Timestep 16600: 8 unique C–F bonds
# Timestep 16650: 8 unique C–F bonds
# Timestep 16700: 8 unique C–F bonds
# Timestep 16750: 8 unique C–F bonds
# Timestep 16800: 8 unique C–F bonds
# Timestep 16850: 8 unique C–F bonds
# Timestep 16900: 9 unique C–F bonds
# Timestep 16950: 9 unique C–F bonds
# Timestep 17000: 9 unique C–F bonds
# Timestep 17050: 9 unique C–F bonds
# Timestep 17100: 8 unique C–F bonds
# Timestep 17150: 8 unique C–F bonds
# Timestep 17200: 8 unique C–F bonds
# Timestep 17250: 8 unique C–F bonds
# Timestep 17300: 8 unique C–F bonds
# Timestep 17350: 9 unique C–F bonds
# Timestep 17400: 9 unique C–F bonds
# Timestep 17450: 9 unique C–F bonds
# Timestep 17500: 9 unique C–F bonds
# Timestep 17550: 9 unique C–F bonds
# Timestep 17600: 9 unique C–F bonds
# Timestep 17650: 9 unique C–F bonds
# Timestep 17700: 9 unique C–F bonds
# Timestep 17750: 9 unique C–F bonds
# Timestep 17800: 9 unique C–F bonds
# Timestep 17850: 9 unique C–F bonds
# Timestep 17900: 9 unique C–F bonds
# Timestep 17950: 9 unique C–F bonds
# Timestep 18000: 8 unique C–F bonds
# Timestep 18050: 8 unique C–F bonds
# Timestep 18100: 8 unique C–F bonds
# Timestep 18150: 8 unique C–F bonds
# Timestep 18200: 8 unique C–F bonds
# Timestep 18250: 8 unique C–F bonds
# Timestep 18300: 9 unique C–F bonds
# Timestep 18350: 9 unique C–F bonds
# Timestep 18400: 8 unique C–F bonds
# Timestep 18450: 8 unique C–F bonds
# Timestep 18500: 8 unique C–F bonds
# Timestep 18550: 9 unique C–F bonds
# Timestep 18600: 9 unique C–F bonds
# Timestep 18650: 9 unique C–F bonds
# Timestep 18700: 9 unique C–F bonds
# Timestep 18750: 9 unique C–F bonds
# Timestep 18800: 9 unique C–F bonds
# Timestep 18850: 8 unique C–F bonds
# Timestep 18900: 8 unique C–F bonds
# Timestep 18950: 8 unique C–F bonds
# Timestep 19000: 8 unique C–F bonds
# Timestep 19050: 8 unique C–F bonds
# Timestep 19100: 9 unique C–F bonds
# Timestep 19150: 9 unique C–F bonds
# Timestep 19200: 9 unique C–F bonds
# Timestep 19250: 10 unique C–F bonds
# Timestep 19300: 10 unique C–F bonds
# Timestep 19350: 10 unique C–F bonds
# Timestep 19400: 10 unique C–F bonds
# Timestep 19450: 10 unique C–F bonds
# Timestep 19500: 9 unique C–F bonds
# Timestep 19550: 9 unique C–F bonds
# Timestep 19600: 9 unique C–F bonds
# Timestep 19650: 9 unique C–F bonds
# Timestep 19700: 9 unique C–F bonds
# Timestep 19750: 9 unique C–F bonds
# Timestep 19800: 9 unique C–F bonds
# Timestep 19850: 9 unique C–F bonds
# Timestep 19900: 10 unique C–F bonds
# Timestep 19950: 10 unique C–F bonds
# Timestep 20000: 10 unique C–F bonds
# Timestep 20050: 10 unique C–F bonds
# Timestep 20100: 10 unique C–F bonds
# Timestep 20150: 10 unique C–F bonds
# Timestep 20200: 10 unique C–F bonds
# Timestep 20250: 10 unique C–F bonds
# Timestep 20300: 10 unique C–F bonds
# Timestep 20350: 10 unique C–F bonds
# Timestep 20400: 10 unique C–F bonds
# Timestep 20450: 10 unique C–F bonds
# Timestep 20500: 10 unique C–F bonds
# Timestep 20550: 10 unique C–F bonds
# Timestep 20600: 10 unique C–F bonds
# Timestep 20650: 10 unique C–F bonds
# Timestep 20700: 10 unique C–F bonds
# Timestep 20750: 10 unique C–F bonds
# Timestep 20800: 10 unique C–F bonds
# Timestep 20850: 10 unique C–F bonds
# Timestep 20900: 10 unique C–F bonds
# Timestep 20950: 10 unique C–F bonds
# Timestep 21000: 10 unique C–F bonds
# Timestep 21050: 9 unique C–F bonds
# Timestep 21100: 9 unique C–F bonds
# Timestep 21150: 9 unique C–F bonds
# Timestep 21200: 9 unique C–F bonds
# Timestep 21250: 9 unique C–F bonds
# Timestep 21300: 9 unique C–F bonds
# Timestep 21350: 9 unique C–F bonds
# Timestep 21400: 9 unique C–F bonds
# Timestep 21450: 9 unique C–F bonds
# Timestep 21500: 9 unique C–F bonds
# Timestep 21550: 9 unique C–F bonds
# Timestep 21600: 9 unique C–F bonds
# Timestep 21650: 9 unique C–F bonds
# Timestep 21700: 9 unique C–F bonds
# Timestep 21750: 9 unique C–F bonds
# Timestep 21800: 9 unique C–F bonds
# Timestep 21850: 9 unique C–F bonds
# Timestep 21900: 9 unique C–F bonds
# Timestep 21950: 9 unique C–F bonds
# Timestep 22000: 9 unique C–F bonds
# Timestep 22050: 9 unique C–F bonds
# Timestep 22100: 9 unique C–F bonds
# Timestep 22150: 11 unique C–F bonds
# Timestep 22200: 11 unique C–F bonds
# Timestep 22250: 11 unique C–F bonds
# Timestep 22300: 11 unique C–F bonds
# Timestep 22350: 11 unique C–F bonds
# Timestep 22400: 12 unique C–F bonds
# Timestep 22450: 13 unique C–F bonds
# Timestep 22500: 12 unique C–F bonds
# Timestep 22550: 12 unique C–F bonds
# Timestep 22600: 11 unique C–F bonds
# Timestep 22650: 11 unique C–F bonds
# Timestep 22700: 11 unique C–F bonds
# Timestep 22750: 11 unique C–F bonds
# Timestep 22800: 11 unique C–F bonds
# Timestep 22850: 11 unique C–F bonds
# Timestep 22900: 11 unique C–F bonds
# Timestep 22950: 11 unique C–F bonds
# Timestep 23000: 11 unique C–F bonds
# Timestep 23050: 11 unique C–F bonds
# Timestep 23100: 11 unique C–F bonds
# Timestep 23150: 11 unique C–F bonds
# Timestep 23200: 11 unique C–F bonds
# Timestep 23250: 11 unique C–F bonds
# Timestep 23300: 11 unique C–F bonds
# Timestep 23350: 12 unique C–F bonds
# Timestep 23400: 12 unique C–F bonds
# Timestep 23450: 12 unique C–F bonds
# Timestep 23500: 12 unique C–F bonds
# Timestep 23550: 12 unique C–F bonds
# Timestep 23600: 12 unique C–F bonds
# Timestep 23650: 12 unique C–F bonds
# Timestep 23700: 12 unique C–F bonds
# Timestep 23750: 12 unique C–F bonds
# Timestep 23800: 12 unique C–F bonds
# Timestep 23850: 13 unique C–F bonds
# Timestep 23900: 13 unique C–F bonds
# Timestep 23950: 13 unique C–F bonds
# Timestep 24000: 13 unique C–F bonds
# Timestep 24050: 13 unique C–F bonds
# Timestep 24100: 13 unique C–F bonds
# Timestep 24150: 13 unique C–F bonds
# Timestep 24200: 13 unique C–F bonds
# Timestep 24250: 14 unique C–F bonds
# Timestep 24300: 14 unique C–F bonds
# Timestep 24350: 14 unique C–F bonds
# Timestep 24400: 13 unique C–F bonds
# Timestep 24450: 13 unique C–F bonds
# Timestep 24500: 14 unique C–F bonds
# Timestep 24550: 14 unique C–F bonds
# Timestep 24600: 14 unique C–F bonds
# Timestep 24650: 14 unique C–F bonds
# Timestep 24700: 14 unique C–F bonds
# Timestep 24750: 14 unique C–F bonds
# Timestep 24800: 14 unique C–F bonds
# Timestep 24850: 13 unique C–F bonds
# Timestep 24900: 13 unique C–F bonds
# Timestep 24950: 13 unique C–F bonds
# Timestep 25000: 13 unique C–F bonds
# Timestep 25050: 13 unique C–F bonds
# Timestep 25100: 12 unique C–F bonds
# Timestep 25150: 12 unique C–F bonds
# Timestep 25200: 12 unique C–F bonds
# Timestep 25250: 12 unique C–F bonds
# Timestep 25300: 12 unique C–F bonds
# Timestep 25350: 12 unique C–F bonds
# Timestep 25400: 12 unique C–F bonds
# Timestep 25450: 12 unique C–F bonds
# Timestep 25500: 12 unique C–F bonds
# Timestep 25550: 12 unique C–F bonds
# Timestep 25600: 12 unique C–F bonds
# Timestep 25650: 13 unique C–F bonds
# Timestep 25700: 13 unique C–F bonds
# Timestep 25750: 12 unique C–F bonds
# Timestep 25800: 12 unique C–F bonds
# Timestep 25850: 12 unique C–F bonds
# Timestep 25900: 12 unique C–F bonds
# Timestep 25950: 12 unique C–F bonds
# Timestep 26000: 13 unique C–F bonds
# Timestep 26050: 13 unique C–F bonds
# Timestep 26100: 13 unique C–F bonds
# Timestep 26150: 13 unique C–F bonds
# Timestep 26200: 12 unique C–F bonds
# Timestep 26250: 13 unique C–F bonds
# Timestep 26300: 13 unique C–F bonds
# Timestep 26350: 13 unique C–F bonds
# Timestep 26400: 14 unique C–F bonds
# Timestep 26450: 13 unique C–F bonds
# Timestep 26500: 14 unique C–F bonds
# Timestep 26550: 13 unique C–F bonds
# Timestep 26600: 14 unique C–F bonds
# Timestep 26650: 12 unique C–F bonds
# Timestep 26700: 13 unique C–F bonds
# Timestep 26750: 12 unique C–F bonds
# Timestep 26800: 13 unique C–F bonds
# Timestep 26850: 12 unique C–F bonds
# Timestep 26900: 13 unique C–F bonds
# Timestep 26950: 12 unique C–F bonds
# Timestep 27000: 12 unique C–F bonds
# Timestep 27050: 12 unique C–F bonds
# Timestep 27100: 11 unique C–F bonds
# Timestep 27150: 12 unique C–F bonds
# Timestep 27200: 11 unique C–F bonds
# Timestep 27250: 12 unique C–F bonds
# Timestep 27300: 11 unique C–F bonds
# Timestep 27350: 12 unique C–F bonds
# Timestep 27400: 11 unique C–F bonds
# Timestep 27450: 12 unique C–F bonds
# Timestep 27500: 12 unique C–F bonds
# Timestep 27550: 12 unique C–F bonds
# Timestep 27600: 11 unique C–F bonds
# Timestep 27650: 11 unique C–F bonds
# Timestep 27700: 11 unique C–F bonds
# Timestep 27750: 11 unique C–F bonds
# Timestep 27800: 11 unique C–F bonds
# Timestep 27850: 11 unique C–F bonds
# Timestep 27900: 11 unique C–F bonds
# Timestep 27950: 11 unique C–F bonds
# Timestep 28000: 12 unique C–F bonds
# Timestep 28050: 12 unique C–F bonds
# Timestep 28100: 12 unique C–F bonds
# Timestep 28150: 12 unique C–F bonds
# Timestep 28200: 12 unique C–F bonds
# Timestep 28250: 12 unique C–F bonds
# Timestep 28300: 12 unique C–F bonds
# Timestep 28350: 12 unique C–F bonds
# Timestep 28400: 12 unique C–F bonds
# Timestep 28450: 12 unique C–F bonds
# Timestep 28500: 12 unique C–F bonds
# Timestep 28550: 12 unique C–F bonds
# Timestep 28600: 12 unique C–F bonds
# Timestep 28650: 12 unique C–F bonds
# Timestep 28700: 12 unique C–F bonds
# Timestep 28750: 12 unique C–F bonds
# Timestep 28800: 12 unique C–F bonds
# Timestep 28850: 12 unique C–F bonds
# Timestep 28900: 12 unique C–F bonds
# Timestep 28950: 12 unique C–F bonds
# Timestep 29000: 12 unique C–F bonds
# Timestep 29050: 12 unique C–F bonds
# Timestep 29100: 12 unique C–F bonds
# Timestep 29150: 13 unique C–F bonds
# Timestep 29200: 13 unique C–F bonds
# Timestep 29250: 15 unique C–F bonds
# Timestep 29300: 14 unique C–F bonds
# Timestep 29350: 14 unique C–F bonds
# Timestep 29400: 14 unique C–F bonds
# Timestep 29450: 14 unique C–F bonds
# Timestep 29500: 14 unique C–F bonds
# Timestep 29550: 13 unique C–F bonds
# Timestep 29600: 14 unique C–F bonds
# Timestep 29650: 13 unique C–F bonds
# Timestep 29700: 13 unique C–F bonds
# Timestep 29750: 13 unique C–F bonds
# Timestep 29800: 13 unique C–F bonds
# Timestep 29850: 13 unique C–F bonds
# Timestep 29900: 13 unique C–F bonds
# Timestep 29950: 14 unique C–F bonds
# Timestep 30000: 13 unique C–F bonds
# Timestep 30050: 11 unique C–F bonds
# Timestep 30100: 11 unique C–F bonds
# Timestep 30150: 11 unique C–F bonds
# Timestep 30200: 11 unique C–F bonds
# Timestep 30250: 11 unique C–F bonds
# Timestep 30300: 11 unique C–F bonds
# Timestep 30350: 11 unique C–F bonds
# Timestep 30400: 11 unique C–F bonds
# Timestep 30450: 11 unique C–F bonds
# Timestep 30500: 11 unique C–F bonds
# Timestep 30550: 11 unique C–F bonds
# Timestep 30600: 11 unique C–F bonds
# Timestep 30650: 12 unique C–F bonds
# Timestep 30700: 12 unique C–F bonds
# Timestep 30750: 11 unique C–F bonds
# Timestep 30800: 11 unique C–F bonds
# Timestep 30850: 11 unique C–F bonds
# Timestep 30900: 12 unique C–F bonds
# Timestep 30950: 12 unique C–F bonds
# Timestep 31000: 12 unique C–F bonds
# Timestep 31050: 10 unique C–F bonds
# Timestep 31100: 10 unique C–F bonds
# Timestep 31150: 11 unique C–F bonds
# Timestep 31200: 11 unique C–F bonds
# Timestep 31250: 11 unique C–F bonds
# Timestep 31300: 12 unique C–F bonds
# Timestep 31350: 12 unique C–F bonds
# Timestep 31400: 12 unique C–F bonds
# Timestep 31450: 12 unique C–F bonds
# Timestep 31500: 11 unique C–F bonds
# Timestep 31550: 11 unique C–F bonds
# Timestep 31600: 11 unique C–F bonds
# Timestep 31650: 11 unique C–F bonds
# Timestep 31700: 12 unique C–F bonds
# Timestep 31750: 12 unique C–F bonds
# Timestep 31800: 11 unique C–F bonds
# Timestep 31850: 11 unique C–F bonds
# Timestep 31900: 11 unique C–F bonds
# Timestep 31950: 11 unique C–F bonds
# Timestep 32000: 11 unique C–F bonds
# Timestep 32050: 11 unique C–F bonds
# Timestep 32100: 11 unique C–F bonds
# Timestep 32150: 11 unique C–F bonds
# Timestep 32200: 11 unique C–F bonds
# Timestep 32250: 12 unique C–F bonds
# Timestep 32300: 12 unique C–F bonds
# Timestep 32350: 12 unique C–F bonds
# Timestep 32400: 12 unique C–F bonds
# Timestep 32450: 12 unique C–F bonds
# Timestep 32500: 12 unique C–F bonds
# Timestep 32550: 12 unique C–F bonds
# Timestep 32600: 12 unique C–F bonds
# Timestep 32650: 11 unique C–F bonds
# Timestep 32700: 11 unique C–F bonds
# Timestep 32750: 11 unique C–F bonds
# Timestep 32800: 11 unique C–F bonds
# Timestep 32850: 13 unique C–F bonds
# Timestep 32900: 13 unique C–F bonds
# Timestep 32950: 13 unique C–F bonds
# Timestep 33000: 11 unique C–F bonds
# Timestep 33050: 11 unique C–F bonds
# Timestep 33100: 13 unique C–F bonds
# Timestep 33150: 13 unique C–F bonds
# Timestep 33200: 13 unique C–F bonds
# Timestep 33250: 13 unique C–F bonds
# Timestep 33300: 13 unique C–F bonds
# Timestep 33350: 13 unique C–F bonds
# Timestep 33400: 13 unique C–F bonds
# Timestep 33450: 13 unique C–F bonds
# Timestep 33500: 13 unique C–F bonds
# Timestep 33550: 13 unique C–F bonds
# Timestep 33600: 13 unique C–F bonds
# Timestep 33650: 13 unique C–F bonds
# Timestep 33700: 13 unique C–F bonds
# Timestep 33750: 13 unique C–F bonds
# Timestep 33800: 13 unique C–F bonds
# Timestep 33850: 13 unique C–F bonds
# Timestep 33900: 13 unique C–F bonds
# Timestep 33950: 13 unique C–F bonds
# Timestep 34000: 13 unique C–F bonds
# Timestep 34050: 10 unique C–F bonds
# Timestep 34100: 10 unique C–F bonds
# Timestep 34150: 10 unique C–F bonds
# Timestep 34200: 10 unique C–F bonds
# Timestep 34250: 10 unique C–F bonds
# Timestep 34300: 10 unique C–F bonds
# Timestep 34350: 10 unique C–F bonds
# Timestep 34400: 10 unique C–F bonds
# Timestep 34450: 10 unique C–F bonds
# Timestep 34500: 11 unique C–F bonds
# Timestep 34550: 11 unique C–F bonds
# Timestep 34600: 11 unique C–F bonds
# Timestep 34650: 11 unique C–F bonds
# Timestep 34700: 11 unique C–F bonds
# Timestep 34750: 11 unique C–F bonds
# Timestep 34800: 11 unique C–F bonds
# Timestep 34850: 10 unique C–F bonds
# Timestep 34900: 10 unique C–F bonds
# Timestep 34950: 10 unique C–F bonds
# Timestep 35000: 11 unique C–F bonds
# Timestep 35050: 12 unique C–F bonds
# Timestep 35100: 12 unique C–F bonds
# Timestep 35150: 12 unique C–F bonds
# Timestep 35200: 12 unique C–F bonds
# Timestep 35250: 12 unique C–F bonds
# Timestep 35300: 12 unique C–F bonds
# Timestep 35350: 12 unique C–F bonds
# Timestep 35400: 13 unique C–F bonds
# Timestep 35450: 13 unique C–F bonds
# Timestep 35500: 13 unique C–F bonds
# Timestep 35550: 12 unique C–F bonds
# Timestep 35600: 12 unique C–F bonds
# Timestep 35650: 12 unique C–F bonds
# Timestep 35700: 12 unique C–F bonds
# Timestep 35750: 12 unique C–F bonds
# Timestep 35800: 12 unique C–F bonds
# Timestep 35850: 12 unique C–F bonds
# Timestep 35900: 12 unique C–F bonds
# Timestep 35950: 12 unique C–F bonds
# Timestep 36000: 12 unique C–F bonds
# Timestep 36050: 13 unique C–F bonds
# Timestep 36100: 13 unique C–F bonds
# Timestep 36150: 13 unique C–F bonds
# Timestep 36200: 13 unique C–F bonds
# Timestep 36250: 13 unique C–F bonds
# Timestep 36300: 13 unique C–F bonds
# Timestep 36350: 13 unique C–F bonds
# Timestep 36400: 12 unique C–F bonds
# Timestep 36450: 12 unique C–F bonds
# Timestep 36500: 12 unique C–F bonds
# Timestep 36550: 12 unique C–F bonds
# Timestep 36600: 12 unique C–F bonds
# Timestep 36650: 12 unique C–F bonds
# Timestep 36700: 12 unique C–F bonds
# Timestep 36750: 13 unique C–F bonds
# Timestep 36800: 13 unique C–F bonds
# Timestep 36850: 13 unique C–F bonds
# Timestep 36900: 13 unique C–F bonds
# Timestep 36950: 13 unique C–F bonds
# Timestep 37000: 13 unique C–F bonds
# Timestep 37050: 14 unique C–F bonds
# Timestep 37100: 14 unique C–F bonds
# Timestep 37150: 14 unique C–F bonds
# Timestep 37200: 14 unique C–F bonds
# Timestep 37250: 14 unique C–F bonds
# Timestep 37300: 13 unique C–F bonds
# Timestep 37350: 13 unique C–F bonds
# Timestep 37400: 13 unique C–F bonds
# Timestep 37450: 13 unique C–F bonds
# Timestep 37500: 15 unique C–F bonds
# Timestep 37550: 15 unique C–F bonds
# Timestep 37600: 14 unique C–F bonds
# Timestep 37650: 14 unique C–F bonds
# Timestep 37700: 16 unique C–F bonds
# Timestep 37750: 14 unique C–F bonds
# Timestep 37800: 14 unique C–F bonds
# Timestep 37850: 14 unique C–F bonds
# Timestep 37900: 14 unique C–F bonds
# Timestep 37950: 14 unique C–F bonds
# Timestep 38000: 14 unique C–F bonds
# Timestep 38050: 14 unique C–F bonds
# Timestep 38100: 14 unique C–F bonds
# Timestep 38150: 14 unique C–F bonds
# Timestep 38200: 14 unique C–F bonds
# Timestep 38250: 14 unique C–F bonds
# Timestep 38300: 14 unique C–F bonds
# Timestep 38350: 16 unique C–F bonds
# Timestep 38400: 16 unique C–F bonds
# Timestep 38450: 16 unique C–F bonds
# Timestep 38500: 16 unique C–F bonds
# Timestep 38550: 16 unique C–F bonds
# Timestep 38600: 16 unique C–F bonds
# Timestep 38650: 16 unique C–F bonds
# Timestep 38700: 16 unique C–F bonds
# Timestep 38750: 16 unique C–F bonds
# Timestep 38800: 16 unique C–F bonds
# Timestep 38850: 16 unique C–F bonds
# Timestep 38900: 16 unique C–F bonds
# Timestep 38950: 15 unique C–F bonds
# Timestep 39000: 15 unique C–F bonds
# Timestep 39050: 15 unique C–F bonds
# Timestep 39100: 15 unique C–F bonds
# Timestep 39150: 15 unique C–F bonds
# Timestep 39200: 15 unique C–F bonds
# Timestep 39250: 15 unique C–F bonds
# Timestep 39300: 15 unique C–F bonds
# Timestep 39350: 15 unique C–F bonds
# Timestep 39400: 15 unique C–F bonds
# Timestep 39450: 15 unique C–F bonds
# Timestep 39500: 15 unique C–F bonds
# Timestep 39550: 15 unique C–F bonds
# Timestep 39600: 16 unique C–F bonds
# Timestep 39650: 16 unique C–F bonds
# Timestep 39700: 15 unique C–F bonds
# Timestep 39750: 15 unique C–F bonds
# Timestep 39800: 15 unique C–F bonds
# Timestep 39850: 15 unique C–F bonds
# Timestep 39900: 15 unique C–F bonds
# Timestep 39950: 15 unique C–F bonds
# Timestep 40000: 15 unique C–F bonds
# Timestep 40050: 17 unique C–F bonds
